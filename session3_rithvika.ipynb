# %%
import pandas as pd

# %%
df = pd.read_csv('UDISE_2023-24_Table_2.1.csv')

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#    sl._no.               india/state/ut  total_number_of___schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
#
#    total_number_of___enrolments  total_number_of___teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
#
#    percentage_share_of_schools_by_category___primary  \
# 0                                              50.00
# 1                                              50.70
# ...

# %%
df.columns
# Out:
# Index(['sl._no.', 'india/state/ut', 'total_number_of___schools',
#        'total_number_of___enrolments', 'total_number_of___teachers',
#        'percentage_share_of_schools_by_category___primary',
#        'percentage_share_of_schools_by_category___upper_primary',
#        'percentage_share_of_schools_by_category___secondary',
#        'percentage_share_of_schools_by_category___higher_secondary',
#        'percentage_share_of_enrolments_by_level____primary_',
#        'percentage_share_of_enrolments_by_level____upper_primary_',
#        'percentage_share_of_enrolments_by_level___secondary',
#        'percentage_share_of_enrolments_by_level___higher_secondary',
#        'percentage_share_of_teachers_by_school_category___primary',
#        'percentage_share_of_teachers_by_school_category___upper_primary',
#        'percentage_share_of_teachers_by_school_category___secondary',
#        'percentage_share_of_teachers_by_school_category___higher_secondary'],
#       dtype='str')

# %%
df.query("total_number_of___teachers < 50000")
# Out:
#     sl._no.                            india/state/ut  \
# 1         2               Andaman and Nicobar Islands
# 3         4                         Arunachal Pradesh
# 6         7                                Chandigarh
# 8         9  Dadra and Nagar Haveli and Daman and Diu
# 10       11                                       Goa
# 18       19                                    Ladakh
# 19       20                               Lakshadweep
# 22       23                                   Manipur
# 24       25                                   Mizoram
# 25       26                                  Nagaland
# 27       28                                Puducherry
# 30       31                                    Sikkim
# 33       34                                   Tripura
#
#     total_number_of___schools  total_number_of___enrolments  \
# 1                         412                         72119
# 3                        3490                        323717
# ...

# %%
df[df["total_number_of___schools"] < 10000][[
    "india/state/ut",
    "total_number_of___schools"
]].sort_values("total_number_of___schools", ascending=True)
# Out:
#                               india/state/ut  total_number_of___schools
# 19                               Lakshadweep                         37
# 6                                 Chandigarh                        230
# 1                Andaman and Nicobar Islands                        412
# 8   Dadra and Nagar Haveli and Daman and Diu                        432
# 27                                Puducherry                        735
# 18                                    Ladakh                        995
# 30                                    Sikkim                       1254
# 10                                       Goa                       1487
# 25                                  Nagaland                       2725
# 3                          Arunachal Pradesh                       3490
# 24                                   Mizoram                       3941
# 22                                   Manipur                       4646
# ...

# %%
#top 10 states with most enrolments (have used 11 as India is also there)
df.sort_values(
    by="total_number_of___enrolments",
    ascending=False
)[["india/state/ut", "total_number_of___enrolments"]].head(11)
# Out:
#     india/state/ut  total_number_of___enrolments
# 0            India                     248045828
# 34   Uttar Pradesh                      41662794
# 21     Maharashtra                      21375970
# 5            Bihar                      21348149
# 36     West Bengal                      18015525
# 29       Rajasthan                      16786065
# 20  Madhya Pradesh                      15361543
# 31      Tamil Nadu                      12993050
# 16       Karnataka                      11926303
# 11         Gujarat                      11496709
